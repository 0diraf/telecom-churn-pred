# %% [markdown]
# # 📞Telecom Company Customer Churn Prediction
#
#
#
# In this project, I wanted to work with customer attrition data in the telecom industry. However, gaining access to such a dataset on real-world customer churn can be a very difficult task. Because of challenges like data privacy concerns, proprietary restrictions, and ethical considerations, companies often guard their customer data with utmost security, making access to genuine and extensive datasets a rarity.
#
# However, one popular sample dataset that is used to study customer churn is [IBM's Telco Customer Churn sample dataset.](https://accelerator.ca.analytics.ibm.com/bi/?perspective=authoring&pathRef=.public_folders%2FIBM%2BAccelerator%2BCatalog%2FContent%2FDAT00148&id=i9710CF25EF75468D95FFFC7D57D45204&objRef=i9710CF25EF75468D95FFFC7D57D45204&action=run&format=HTML&cmPropStr=%7B%22id%22%3A%22i9710CF25EF75468D95FFFC7D57D45204%22%2C%22type%22%3A%22reportView%22%2C%22defaultName%22%3A%22DAT00148%22%2C%22permissions%22%3A%5B%22execute%22%2C%22read%22%2C%22traverse%22%5D%7D) This dataset is about different characteristics of customers of a fictional telecom company operating in Californa.

# %% [markdown]
# ##✅ Objectives
#
#  The main objectives of this project are:
#
# * Examine and pre-process the different datasets containing user characteristics
# * Perform Exploratory Data Analysis (EDA) to uncover any underlying insights in the dataset
# * Build a model that predicts whether or not a user will leave the telecom company's services

# %% [markdown]
# ## 🔤 Data Description
#
# There are a number of tables containing information about user characteristics such as demographics, what services they have purchased, etc.
#
# The tables contain a number of features. The details of each of the features for each of the tables are given below:
#
# ### Demographics
# * **CustomerID**: A unique ID that identifies each customer.
#
# * **Count**: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# * **Gender**: The customer’s gender: Male, Female
#
# * **Age**: The customer’s current age, in years, at the time the fiscal quarter ended.
#
# * **Senior Citizen**: Indicates if the customer is 65 or older: Yes, No
#
# * **Married**: Indicates if the customer is married: Yes, No
#
# * **Dependents**: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
#
# * **Number of Dependents**: Indicates the number of dependents that live with the customer.
#
# ### Location
# * **CustomerID**: A unique ID that identifies each customer.
#
# * **Count**: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# * **Country**: The country of the customer’s primary residence.
#
# * **State**: The state of the customer’s primary residence.
#
# * **City**: The city of the customer’s primary residence.
#
# * **Zip Code**: The zip code of the customer’s primary residence.
#
# * **Lat Long**: The combined latitude and longitude of the customer’s primary residence.
#
# * **Latitude**: The latitude of the customer’s primary residence.
#
# * **Longitude**: The longitude of the customer’s primary residence.
#
#
#
# ###Population
#
# * **ID**: A unique ID that identifies each row.
#
# * **Zip Code**: The zip code of the customer’s primary residence.
#
# * **Population**: A current population estimate for the entire Zip Code area.
#
#
#
# ###Services
#
# * **CustomerID**: A unique ID that identifies each customer.
#
# * **Count**: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# * **Quarter**: The fiscal quarter that the data has been derived from (e.g. Q3).
#
# * **Referred a Friend**: Indicates if the customer has ever referred a friend or family member to this company: Yes, No
#
# * **Number of Referrals**: Indicates the number of referrals to date that the customer has made.
#
# * **Tenure in Months**: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
#
# * **Offer**: Identifies the last marketing offer that the customer accepted, if applicable. Values include None, Offer A, Offer B, Offer C, Offer D, and Offer E.
#
# * **Phone Service**: Indicates if the customer subscribes to home phone service with the company: Yes, No
#
# * **Avg Monthly Long Distance Charges**: Indicates the customer’s average long distance charges, calculated to the end of the quarter specified above.
#
# * **Multiple Lines**: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
#
# * **Internet Service**: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
# * **Avg Monthly GB Download**: Indicates the customer’s average download volume in gigabytes, calculated to the end of the quarter specified above.
#
# * **Online Security**: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
#
# * **Online Backup**: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
#
# * **Device Protection Plan**: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
#
# * **Premium Tech Support**: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
# * **Streaming TV**: Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# * **Streaming Movies**: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# * **Streaming Music**: Indicates if the customer uses their Internet service to stream music from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# * **Unlimited Data**: Indicates if the customer has paid an additional monthly fee to have unlimited data downloads/uploads: Yes, No
#
# * **Contract**: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
# * **Paperless Billing**: Indicates if the customer has chosen paperless billing: Yes, No
#
# * **Payment Method**: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
#
# * **Monthly Charge**: Indicates the customer’s current total monthly charge for all their services from the company.
#
# * **Total Charges**: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
# * **Total Refunds**: Indicates the customer’s total refunds, calculated to the end of the quarter specified above.
#
# * **Total Extra Data Charges**: Indicates the customer’s total charges for extra data downloads above those specified in their plan, by the end of the quarter specified above.
#
# * **Total Long Distance Charges**: Indicates the customer’s total charges for long distance above those specified in their plan, by the end of the quarter specified above.
#
#
#
# ###Status
#
# * **CustomerID**: A unique ID that identifies each customer.
#
# * **Count**: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# * **Quarter**: The fiscal quarter that the data has been derived from (e.g. Q3).
#
# * **Satisfaction Score**: A customer’s overall satisfaction rating of the company from 1 (Very Unsatisfied) to 5 (Very Satisfied).
#
# * **Satisfaction Score Label**: Indicates the text version of the score (1-5) as a text string.
#
# * **Customer Status**: Indicates the status of the customer at the end of the quarter: Churned, Stayed, or Joined
#
# * **Churn Label**: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
#
# * **Churn Value**: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
#
# * **Churn Score**: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
#
# * **Churn Score Category**: A calculation that assigns a Churn Score to one of the following categories: 0-10, 11-20, 21-30, 31-40, 41-50, 51-60, 61-70, 71-80, 81-90, and 91-100
#
# * **CLTV**: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
#
# * **CLTV Category**: A calculation that assigns a CLTV value to one of the following categories: 2000-2500, 2501-3000, 3001-3500, 3501-4000, 4001-4500, 4501-5000, 5001-5500, 5501-6000, 6001-6500, and 6501-7000.
#
# * **Churn Category**: A high-level category for the customer’s reason for churning: Attitude, Competitor, Dissatisfaction, Other, Price. When they leave the company, all customers are asked about their reasons for leaving. Directly related to Churn Reason.
#
# * **Churn Reason**: A customer’s specific reason for leaving the company. Directly related to Churn Category.

# %%
# !pip install cartopy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 20.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 4.2 MB/s eta 0:00:00
# ...
#   Created wheel for cartopy: filename=Cartopy-0.21.1-cp310-cp310-linux_x86_64.whl size=11080586 sha256=e309d78f5ba3273e086f8ef26b8163dc6b2d9b63da6677ea7d08ea2884a260aa
#   Stored in directory: /root/.cache/pip/wheels/30/b0/1a/1c1909e00c76653dc4e2ff48555257c0eb2d1698280c8d9955
# Successfully built cartopy
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl
import cartopy
import cartopy.crs as ccrs

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## ⚙ Data Pre-processing
#
# First, I consolidate the data from the different tables into one DataFrame

# %%
churn = pd.read_excel("Telco_customer_churn.xlsx")
demographics = pd.read_excel("Telco_customer_churn_demographics.xlsx")
location = pd.read_excel("Telco_customer_churn_location.xlsx")
population = pd.read_excel("Telco_customer_churn_population.xlsx")
services = pd.read_excel("Telco_customer_churn_services.xlsx")
churn_status = pd.read_excel("Telco_customer_churn_status.xlsx")

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
demographics.rename(columns={"Customer ID": "CustomerID"}, inplace=True)
demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            7043 non-null   object
#  1   Count                 7043 non-null   int64
#  2   Gender                7043 non-null   object
#  3   Age                   7043 non-null   int64
#  4   Under 30              7043 non-null   object
#  5   Senior Citizen        7043 non-null   object
#  6   Married               7043 non-null   object
#  7   Dependents            7043 non-null   object
#  8   Number of Dependents  7043 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 495.3+ KB

# %%
d_churn = pd.merge(churn, demographics, on="CustomerID", suffixes=('', '_y'))
d_churn.drop(d_churn.filter(regex='_y$').columns, axis=1, inplace=True)

# %%
d_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            7043 non-null   object
#  1   Count                 7043 non-null   int64
#  2   Country               7043 non-null   object
#  3   State                 7043 non-null   object
#  4   City                  7043 non-null   object
#  5   Zip Code              7043 non-null   int64
#  6   Lat Long              7043 non-null   object
#  7   Latitude              7043 non-null   float64
#  8   Longitude             7043 non-null   float64
#  9   Gender                7043 non-null   object
#  10  Senior Citizen        7043 non-null   object
#  11  Partner               7043 non-null   object
#  12  Dependents            7043 non-null   object
#  13  Tenure Months         7043 non-null   int64
#  14  Phone Service         7043 non-null   object
# ...

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          1671 non-null   int64
#  1   Zip Code    1671 non-null   int64
#  2   Population  1671 non-null   int64
# dtypes: int64(3)
# memory usage: 39.3 KB

# %%
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location ID  7043 non-null   object
#  1   Customer ID  7043 non-null   object
#  2   Count        7043 non-null   int64
#  3   Country      7043 non-null   object
#  4   State        7043 non-null   object
#  5   City         7043 non-null   object
#  6   Zip Code     7043 non-null   int64
#  7   Lat Long     7043 non-null   object
#  8   Latitude     7043 non-null   float64
#  9   Longitude    7043 non-null   float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 550.4+ KB

# %%
population.rename(columns={"ID": "Location ID"}, inplace=True)

# %%
p_location = pd.merge(population, location, suffixes = ("", "_y"), on = "Zip Code")
p_location.drop(p_location.filter(regex='_y$').columns, axis=1, inplace=True)

# %%
p_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location ID  7043 non-null   int64
#  1   Zip Code     7043 non-null   int64
#  2   Population   7043 non-null   int64
#  3   Customer ID  7043 non-null   object
#  4   Count        7043 non-null   int64
#  5   Country      7043 non-null   object
#  6   State        7043 non-null   object
#  7   City         7043 non-null   object
#  8   Lat Long     7043 non-null   object
#  9   Latitude     7043 non-null   float64
#  10  Longitude    7043 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 660.3+ KB

# %%
p_location.rename(columns={"Customer ID": "CustomerID"}, inplace=True)

# %%
pld_churn = pd.merge(d_churn, p_location, on = "CustomerID", suffixes = ("", "_y"))
pld_churn.drop(pld_churn.filter(regex='_y$').columns, axis=1, inplace=True)

# %%
pld_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            7043 non-null   object
#  1   Count                 7043 non-null   int64
#  2   Country               7043 non-null   object
#  3   State                 7043 non-null   object
#  4   City                  7043 non-null   object
#  5   Zip Code              7043 non-null   int64
#  6   Lat Long              7043 non-null   object
#  7   Latitude              7043 non-null   float64
#  8   Longitude             7043 non-null   float64
#  9   Gender                7043 non-null   object
#  10  Senior Citizen        7043 non-null   object
#  11  Partner               7043 non-null   object
#  12  Dependents            7043 non-null   object
#  13  Tenure Months         7043 non-null   int64
#  14  Phone Service         7043 non-null   object
# ...

# %%
churn_status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Status ID           7043 non-null   object
#  1   Customer ID         7043 non-null   object
#  2   Count               7043 non-null   int64
#  3   Quarter             7043 non-null   object
#  4   Satisfaction Score  7043 non-null   int64
#  5   Customer Status     7043 non-null   object
#  6   Churn Label         7043 non-null   object
#  7   Churn Value         7043 non-null   int64
#  8   Churn Score         7043 non-null   int64
#  9   CLTV                7043 non-null   int64
#  10  Churn Category      1869 non-null   object
#  11  Churn Reason        1869 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 660.4+ KB

# %%
churn_status.rename(columns = {"Customer ID": "CustomerID"}, inplace=True)

# %%
spld_churn = pd.merge(pld_churn, churn_status, on="CustomerID", suffixes = ("", "_y"))
spld_churn.drop(spld_churn.filter(regex='_y$').columns, axis=1, inplace=True)

# %%
spld_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 44 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            7043 non-null   object
#  1   Count                 7043 non-null   int64
#  2   Country               7043 non-null   object
#  3   State                 7043 non-null   object
#  4   City                  7043 non-null   object
#  5   Zip Code              7043 non-null   int64
#  6   Lat Long              7043 non-null   object
#  7   Latitude              7043 non-null   float64
#  8   Longitude             7043 non-null   float64
#  9   Gender                7043 non-null   object
#  10  Senior Citizen        7043 non-null   object
#  11  Partner               7043 non-null   object
#  12  Dependents            7043 non-null   object
#  13  Tenure Months         7043 non-null   int64
#  14  Phone Service         7043 non-null   object
# ...

# %%
services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Service ID                         7043 non-null   object
#  1   Customer ID                        7043 non-null   object
#  2   Count                              7043 non-null   int64
#  3   Quarter                            7043 non-null   object
#  4   Referred a Friend                  7043 non-null   object
#  5   Number of Referrals                7043 non-null   int64
#  6   Tenure in Months                   7043 non-null   int64
#  7   Offer                              7043 non-null   object
#  8   Phone Service                      7043 non-null   object
#  9   Avg Monthly Long Distance Charges  7043 non-null   float64
#  10  Multiple Lines                     7043 non-null   object
# ...

# %%
services.rename(columns={"Customer ID": "CustomerID"}, inplace=True)

# %%
churn_df = pd.merge(spld_churn, services, on="CustomerID", suffixes = ("", "_y"))
churn_df.drop(churn_df.filter(regex='_y$').columns, axis=1, inplace=True)

# %% [markdown]
# Now that the data is consolidated, I try to drop any redundant or less useful features from the DataFrame.

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 61 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CustomerID                         7043 non-null   object
#  1   Count                              7043 non-null   int64
#  2   Country                            7043 non-null   object
#  3   State                              7043 non-null   object
#  4   City                               7043 non-null   object
#  5   Zip Code                           7043 non-null   int64
#  6   Lat Long                           7043 non-null   object
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Gender                             7043 non-null   object
#  10  Senior Citizen                     7043 non-null   object
# ...

# %%
churn_df[["Partner", "Married"]]
# Out:
#      Partner Married
# 0         No      No
# 1         No      No
# 2         No      No
# 3        Yes     Yes
# 4         No      No
# ...      ...     ...
# 7038      No      No
# 7039     Yes     Yes
# 7040     Yes     Yes
# 7041     Yes     Yes
# 7042      No      No
#
# [7043 rows x 2 columns]

# %%
churn_df.Partner.equals(churn_df.Married)
# Out:
# True

# %% [markdown]
# The features "Partner" and "Married" are effectively the same so one of them can be dropped.

# %%
churn_df[["Tenure Months", "Tenure in Months"]]
# Out:
#       Tenure Months  Tenure in Months
# 0                 2                 2
# 1                 2                 2
# 2                 8                 8
# 3                28                28
# 4                49                49
# ...             ...               ...
# 7038             72                72
# 7039             24                24
# 7040             72                72
# 7041             11                11
# 7042             66                66
#
# [7043 rows x 2 columns]

# %% [markdown]
# Tenure Months and Tenure in Months also appear to be the same so we can drop one of these features.

# %%
churn_df["Customer Status"].value_counts()
# Out:
# Stayed     4720
# Churned    1869
# Joined      454
# Name: Customer Status, dtype: int64

# %%
churn_df["Churn Label"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn Label, dtype: int64

# %% [markdown]
# We can drop the Customer status column as it is of not much use to us.

# %%
churn_df["Internet Service"].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: Internet Service, dtype: int64

# %%
churn_df["Internet Type"].value_counts()
# Out:
# Fiber Optic    3035
# DSL            1652
# None           1526
# Cable           830
# Name: Internet Type, dtype: int64

# %% [markdown]
# The Internet Service and Internet Type columns are basically the same. However, the Internet Type features carries a little bit more information as compared to Internet Service feature, which is why Internet Service feature can be dropped.

# %%
churn_df["Online Security"].value_counts()
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: Online Security, dtype: int64

# %%
churn_df.Quarter.value_counts()
# Out:
# Q3    7043
# Name: Quarter, dtype: int64

# %% [markdown]
# All of the observations are from the third quarter so this feature is useless.

# %% [markdown]
# We can also drop the ID columns, Count, Zip Code (as we have latitude and longitudes available in separate columns), Population, Referred a Friend (as we have number of referrals feature available), Dependents (as we have Number of Dependents feature available), Monthly Charge features (as we have total charges available), Country and State (all observations are from California, USA), and finally the Churn Value column as we have the Churn Label column available.

# %%
churn_df.drop(["CustomerID", "Count", "Location ID", "Service ID", "Status ID", "Zip Code",
               "Lat Long", "Churn Reason", "Referred a Friend", "Population", "Dependents",
               "Partner", "Monthly Charge", "Monthly Charges", "Tenure Months",
               "Customer Status", "Churn Value",
               "Internet Service", "Country", "State", "Quarter"], axis=1, inplace=True)

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   City                               7043 non-null   object
#  1   Latitude                           7043 non-null   float64
#  2   Longitude                          7043 non-null   float64
#  3   Gender                             7043 non-null   object
#  4   Senior Citizen                     7043 non-null   object
#  5   Phone Service                      7043 non-null   object
#  6   Multiple Lines                     7043 non-null   object
#  7   Online Security                    7043 non-null   object
#  8   Online Backup                      7043 non-null   object
#  9   Device Protection                  7043 non-null   object
#  10  Tech Support                       7043 non-null   object
# ...

# %%
churn_df["Total Charges"] = churn_df["Total Charges"].replace(" ", 0)

# %%
churn_df["Total Charges"] = churn_df["Total Charges"].astype("float64")

# %%
churn_df["Total Charges"]
# Out:
# 0        108.15
# 1        151.65
# 2        820.50
# 3       3046.05
# 4       5036.30
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
churn_df.head()
# Out:
#           City   Latitude   Longitude  Gender Senior Citizen Phone Service  \
# 0  Los Angeles  33.964131 -118.272783    Male             No           Yes
# 1  Los Angeles  34.059281 -118.307420  Female             No           Yes
# 2  Los Angeles  34.048013 -118.293953  Female             No           Yes
# 3  Los Angeles  34.062125 -118.315709  Female             No           Yes
# 4  Los Angeles  34.039224 -118.266293    Male             No           Yes
#
#   Multiple Lines Online Security Online Backup Device Protection  ...  \
# 0             No             Yes           Yes                No  ...
# 1             No              No            No                No  ...
# 2            Yes              No            No               Yes  ...
# 3            Yes              No            No               Yes  ...
# 4            Yes              No           Yes               Yes  ...
#
#   Internet Type Avg Monthly GB Download Device Protection Plan  \
# ...

# %%
churn_df.isna().sum()
# Out:
# City                                    0
# Latitude                                0
# Longitude                               0
# Gender                                  0
# Senior Citizen                          0
# Phone Service                           0
# Multiple Lines                          0
# Online Security                         0
# Online Backup                           0
# Device Protection                       0
# Tech Support                            0
# Streaming TV                            0
# Streaming Movies                        0
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Total Charges                           0
# Churn Label                             0
# Churn Score                             0
# CLTV                                    0
# Age                                     0
# Under 30                                0
# ...

# %%
churn_df.isna().sum().sum()
# Out:
# 5174

# %%
churn_df["Churn Category"].value_counts()
# Out:
# Competitor         841
# Attitude           314
# Dissatisfaction    303
# Price              211
# Other              200
# Name: Churn Category, dtype: int64

# %%
churn_df["Churn Category"].value_counts().sum()
# Out:
# 1869

# %%
churn_df["Churn Label"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn Label, dtype: int64

# %%
churn_df["Churn Category"] = churn_df["Churn Category"].fillna("No churn")

# %%
churn_df["Churn Category"].value_counts()
# Out:
# No churn           5174
# Competitor          841
# Attitude            314
# Dissatisfaction     303
# Price               211
# Other               200
# Name: Churn Category, dtype: int64

# %%
churn_df.isna().sum().sum()
# Out:
# 0

# %%
len(churn_df)
# Out:
# 7043

# %%
churn_df.drop_duplicates(inplace=True)

# %%
len(churn_df)
# Out:
# 7043

# %%
churn_df.head()
# Out:
#           City   Latitude   Longitude  Gender Senior Citizen Phone Service  \
# 0  Los Angeles  33.964131 -118.272783    Male             No           Yes
# 1  Los Angeles  34.059281 -118.307420  Female             No           Yes
# 2  Los Angeles  34.048013 -118.293953  Female             No           Yes
# 3  Los Angeles  34.062125 -118.315709  Female             No           Yes
# 4  Los Angeles  34.039224 -118.266293    Male             No           Yes
#
#   Multiple Lines Online Security Online Backup Device Protection  ...  \
# 0             No             Yes           Yes                No  ...
# 1             No              No            No                No  ...
# 2            Yes              No            No               Yes  ...
# 3            Yes              No            No               Yes  ...
# 4            Yes              No           Yes               Yes  ...
#
#   Internet Type Avg Monthly GB Download Device Protection Plan  \
# ...

# %% [markdown]
# ## 📊 Exploratory Data Analysis
#
# We can get more insights into customer churn characteristics by grouping the data on the basis of City.

# %%
city_group = churn_df.groupby("City")

# %%
city_group.ngroups
# Out:
# 1129

# %%
city_group.size().sort_values(ascending=False)[:10]
# Out:
# City
# Los Angeles      305
# San Diego        150
# San Jose         112
# Sacramento       108
# San Francisco    104
# Fresno            64
# Long Beach        60
# Oakland           52
# Stockton          44
# Bakersfield       40
# dtype: int64

# %% [markdown]
# It appears that there are customers in the dataset from 1,129 cities across the state of California. Let's visualize the customers in top 5 cities on a map of California.

# %%
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': ccrs.PlateCarree()})

# Set the extent to focus on California
ax.set_extent([-125, -113, 32, 42], ccrs.PlateCarree())

ax.add_feature(cartopy.feature.COASTLINE)
ax.add_feature(cartopy.feature.BORDERS, linestyle=':')
ax.add_feature(cartopy.feature.STATES)

# Plot the latitude and longitude points on the map
ax.scatter(churn_df['Longitude'], churn_df['Latitude'], s=30, color='lightblue', marker='o', label='Customers', transform=ccrs.PlateCarree())

# Filter data to include only major cities
major_cities = ['Los Angeles', 'San Diego', 'San Jose', "Sacramento", "San Francisco"]
major_data = {key: [churn_df[key][i] for i in range(len(churn_df['City'])) if churn_df['City'][i] in major_cities] for key in churn_df}


labeled_cities = set()
for city, lat, lon in zip(major_data['City'], major_data['Latitude'], major_data['Longitude']):
    if city not in labeled_cities:
        ax.text(lon, lat, city, transform=ccrs.Geodetic(), fontsize=12, weight='bold')
        ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.Geodetic(), zorder=10, label="City")
        labeled_cities.add(city)

plt.title('Telco Customers in California')

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_1_states_provinces_lakes.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# For the purposes of this analysis, top 3 cities on the basis of number of users are selected for further analysis.

# %%
la = city_group.get_group("Los Angeles")
sd = city_group.get_group("San Diego")
sj = city_group.get_group("San Jose")

# %%
la.head()
# Out:
#           City   Latitude   Longitude  Gender Senior Citizen Phone Service  \
# 0  Los Angeles  33.964131 -118.272783    Male             No           Yes
# 1  Los Angeles  34.059281 -118.307420  Female             No           Yes
# 2  Los Angeles  34.048013 -118.293953  Female             No           Yes
# 3  Los Angeles  34.062125 -118.315709  Female             No           Yes
# 4  Los Angeles  34.039224 -118.266293    Male             No           Yes
#
#   Multiple Lines Online Security Online Backup Device Protection  ...  \
# 0             No             Yes           Yes                No  ...
# 1             No              No            No                No  ...
# 2            Yes              No            No               Yes  ...
# 3            Yes              No            No               Yes  ...
# 4            Yes              No           Yes               Yes  ...
#
#   Internet Type Avg Monthly GB Download Device Protection Plan  \
# ...

# %%
la.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305 entries, 0 to 6771
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   City                               305 non-null    object
#  1   Latitude                           305 non-null    float64
#  2   Longitude                          305 non-null    float64
#  3   Gender                             305 non-null    object
#  4   Senior Citizen                     305 non-null    object
#  5   Phone Service                      305 non-null    object
#  6   Multiple Lines                     305 non-null    object
#  7   Online Security                    305 non-null    object
#  8   Online Backup                      305 non-null    object
#  9   Device Protection                  305 non-null    object
#  10  Tech Support                       305 non-null    object
# ...

# %%
sns.set_theme(style="darkgrid", palette="muted")
sns.despine()
sns.countplot(data=la, x="Gender")
plt.title("Users by Gender in Los Angeles")
plt.show()

# %% [markdown]
# The distribution of users across genders in Los Angeles contains more Female users than Male users

# %%
sns.countplot(data=la, x="Churn Label", hue="Senior Citizen", hue_order=["Yes", "No"])
plt.title("Senior Citizen Churn in Los Angeles")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# In Los Angeles, majority of the users who are senior citizens have not churned.

# %%
sns.countplot(data=la, x="Churn Label", hue="Under 30", hue_order=["Yes", "No"])
plt.title("Under 30 Churn in Los Angeles")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# Majority of the Under 30 users in Los Angeles have not churned.

# %%
sns.countplot(data=la, x="Churn Category")
plt.title("Churn by Category in Los Angeles")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# In Los Angeles, the top 3 reasons given by a customer for leaving the services of the telecom company are (in order):
#
# * Switching to a competitor
# * High price
# * Dissatisfaction with services
#
# In the context of Los Angeles, it could be beneficial to pay attention towards competitors' services, and pricing while also improving our own services to minimize churn due to price concerns and dissastisfcation with our services.

# %%
sns.countplot(data=la, x="Contract", hue="Churn Label", hue_order=["Yes", "No"])
plt.title("Counts of Contract Types by Churn in Los Angeles")
plt.show()

# %% [markdown]
# Most of the users in Los Angeles who have churned follow a month-to-month contract with very little churned users following a one-year contract and almost no churned user on a two year contract. As month-to-month contract users are therefore likely to churn, it could be beneficial to monitor such users and target them with specifically tailored packages to avoid churning.

# %%
sns.countplot(data=la, x="Offer", hue="Churn Label", hue_order=["Yes", "No"])
plt.title("Counts of Offer Types by Churn in Los Angeles")
plt.show()

# %% [markdown]
# Customers who have not accepted any of the last marketing offers are more likely to churn as compared to those who accepted any of the last marketing offers.

# %%
sns.countplot(data=la, x="Internet Type", hue="Churn Label", hue_order=["Yes", "No"])
plt.title("Counts of Internet Types by Churn in Los Angeles")
plt.show()

# %% [markdown]
# Most of the users in Los Angeles who have churned had a fiber optic internet connection. We know that most of the users in Los Angeles churn as they switch to our competitors. Perhaps our fiber optic services do not perform as well as our competitors. Analyzing our competitors and based on that analysis, improving the performance of our fiber optic lines could help reduce the churn rate of our customers.

# %%
sns.boxplot(data=la, x="Churn Label", y="CLTV")
plt.title("Boxplot of Customer Lifetime Value vs Churn in Los Angeles")
plt.ylabel("Customer Lifetime Value")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# It can be observed that the median customer lifetime value of the customers that we have been able to retain is higher than that of the customers that have churned. However, the top whisker of the boxplot representing churn customers extends above 6000 which is concerning as it means some users with high customer lifetive values in Los Angeles have also churned.
#
# Coupled with the fact that most users in Los Angeles churn either due to Competitors, Pricing, or Dissatisfaction, a more thorough competitor analysis as well as efforts to improve our own services and making them more affordable could perhaps reduce the churn rate of customers with customer lifetime values in Los Angeles

# %%
plt.pie(la["Churn Label"].value_counts().to_list(), labels = ["Not Churned", "Churned"], autopct = '%1.1f%%')
plt.title("Pie chart of Churned vs Not Churned in Los Angeles")
plt.show()

# %% [markdown]
# We have been able to retain 70.5% of the users in Los Angeles, however out of the 29.5% who have churned, there are some customers with high customer lifetime values as observed through the box plot.

# %% [markdown]
# After analyzing Los Angeles city, we move towards the analysis of city of San Diego.

# %%
sns.countplot(data=sd, x="Gender")
plt.title("Users by Gender in San Diego")
plt.show()

# %% [markdown]
# The proportion of Male users and Female users in San Diego is approximately the same.

# %%
sns.countplot(data=sd, x="Churn Label", hue="Senior Citizen", hue_order=["Yes", "No"])
plt.title("Senior Citizen Churn in San Diego")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# Similar to Los Angeles, most senior citizens in San Diego do not leave the services of our telecom company.

# %%
sns.countplot(data=sd, x="Churn Label", hue="Under 30", hue_order=["Yes", "No"])
plt.title("Under 30 Churn in San Diego")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# Just like in Los Angeles, most Under 30 users in San Diego have not churned.

# %%
sns.countplot(data=sd, x="Churn Category")
plt.title("Churn by Category in San Diego")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# In Los Angeles, the reasons why customers churned were (in order): Switiching to a competitor, Price, and Dissatisfaction with services. However in San Diego, in addition to switching to a competitor, the reasons why customers churn are due to "Attitude" and "Dissatisfaction". For San Diego specifically, further training of the customer support staff to aid them in solving customer complaints more efficiently could help reduce the churn rate in the city.

# %%
sns.countplot(data=sd, x="Contract", hue="Churn Label")
plt.title("Counts of Contract Types by Churn in San Diego")
plt.show()

# %% [markdown]
# Similar to Los Angeles, most of the churned users were on a month-to-month contract. However, some on two-year and one-year contracts have also churned.

# %%
sns.countplot(data=sd, x="Offer", hue="Churn Label", hue_order=["Yes", "No"])
plt.title("Counts of Offer Types by Churn in San Diego")
plt.show()

# %% [markdown]
# In San Diego, customers who have not accepted any of the last marketing offers are more likely to churn as compared to those who accepted any of the last marketing offers. Customers who have accepted marketing offer E are also likely to churn. Restructuring Offer E and adding additional incentives could help lower churn rate.

# %%
sns.countplot(data=sd, x="Internet Type", hue="Churn Label", hue_order=["Yes", "No"])
plt.title("Counts of Internet Types by Churn in San Diego")
plt.show()

# %% [markdown]
# Similar to Los Angeles, most of the users in San Diego who have churned had a fiber optic internet connection.

# %%
sns.boxplot(data=sd, x="Churn Label", y="CLTV")
plt.title("Boxplot of Customer Lifetime Value vs Churn in San Diego")
plt.ylabel("Customer Lifetime Value")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# Our company has been able to retain customers in San Diego with higher median customer lifetime values, just like in Los Angeles. Furthermore, customers with greater max customer lifetime value have been retained as compared to Los Angeles.

# %%
plt.pie(sd["Churn Label"].value_counts().to_list(), labels = ["Not Churned", "Churned"], autopct = '%1.1f%%')
plt.title("Pie chart of Churned vs Not Churned in San Diego")
plt.show()

# %% [markdown]
# Although customers with higher customer lifetime values have been retained in San Diego, we have not been able to retain a greater percentage of users as compared to Los Angeles.

# %%
sns.countplot(data=sj, x="Gender")
plt.title("Users by Gender in San Jose")
plt.show()

# %% [markdown]
# Unlike Los Angeles and San Diego, Male users in San Jose outnumber the Female users.

# %%
sns.countplot(data=sj, x="Churn Label", hue="Senior Citizen", hue_order=["Yes", "No"])
plt.title("Senior Citizen Churn in San Jose")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# Just like Los Angeles and San Diego, senior citizen users are unlikely to leave our services.

# %%
sns.countplot(data=la, x="Churn Label", hue="Under 30", hue_order=["Yes", "No"])
plt.title("Under 30 Churn in San Jose")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# Just like Los Angeles and San Diego, under 30 users are unlikely to leave our services.

# %%
sns.countplot(data=sj, x="Churn Category")
plt.title("Churn by Category in San Jose")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Most of the churned users in San Jose switched a competitor's services, just like in Los Angeles and San Diego. However, aside from switching to a competitor, most churned users cited being dissatisfied with our services and our pricing as reasons for leaving. Many churned users in San Jose also cited other reasons for leaving.

# %%
sns.countplot(data=sj, x="Contract", hue="Churn Label")
plt.title("Counts of Contract Types by Churn in San Jose")
plt.show()

# %% [markdown]
# Similar to Los Angeles and San Diego, majority of churned users in San Jose were on a month-to-month contract

# %%
sns.countplot(data=sj, x="Offer", hue="Churn Label", hue_order=["Yes", "No"])
plt.title("Counts of Offer Types by Churn in San Jose")
plt.show()

# %% [markdown]
# We have mostly been able to retain more San Jose users, even those who didn't accept any of the last marketting offers, as compared to Los Angeles and San Diego. An important thing to note is that some customers who accepted Offer D churned in San Jose. However, none of the customers who had accepted Offer D in San Diego churned. This indicates a need to customize marketing offers depending upon in which city the user resides.

# %%
sns.countplot(data=sj, x="Internet Type", hue="Churn Label", hue_order=["Yes", "No"])
plt.title("Counts of Internet Types by Churn in San Jose")
plt.show()

# %% [markdown]
# Similar to Los Angeles and San Diego, most of the users in San Jose who have churned had a fiber optic internet connection.

# %%
sns.boxplot(data=sj, x="Churn Label", y="CLTV")
plt.title("Boxplot of Customer Lifetime Value vs Churn in San Jose")
plt.ylabel("Customer Lifetime Value")
plt.xlabel("Churn")
plt.show()

# %% [markdown]
# Similar to Los Angeles and San Diego, the median customer lifetime value of retained users is higher than that of churned users in San Jose.

# %%
plt.pie(sj["Churn Label"].value_counts().to_list(), labels = ["Not Churned", "Churned"], autopct = '%1.1f%%')
plt.title("Pie chart of Churned vs Not Churned in San Jose")
plt.show()

# %% [markdown]
# We have been able to retain a majority of our users (74.1%) in San Jose.

# %% [markdown]
# We can visualize the number of churned users and as well as reasons for churn for the overall state of California and all the cities in which we have users.

# %%
plt.pie(churn_df["Churn Label"].value_counts().to_list(), labels = ["Not Churned", "Churned"], autopct = '%1.1f%%')
plt.title("Pie chart of Churned vs Not Churned (Overall)")
plt.show()

# %%
sns.countplot(data=churn_df, x="Churn Category")
plt.title("Churn by Category (Overall)")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Although we have been able to retain a majority of our users, out of the 26.5% of users that have churned, we can see that the top reasons cited are switching to a competitor, dissatisfaction, and attitude. As stated earlier, churn due to Attitude represents a portion of our customer base that is retainable with some improvements in the customer service protocols/training. On the other hand, churn due to a competitor, price and dissatisfaction can only be reduced if we conduct a thorough competitor analysis as well as an internal analysis for the purposes of optimizing and improving our services.

# %%
g = sns.FacetGrid(data=churn_df, col="Churn Label", palette='husl', hue="Satisfaction Score", height=4.5, aspect=1.75)
g.map_dataframe(sns.countplot, "Online Security")
g.add_legend()
g.fig.suptitle('Customer Churn with Online Security by Satisfaction Score', fontsize=12)
plt.show()

# %% [markdown]
# We can see that the satisfaction scores for customers who churned with the Online Security service are very low.

# %%
g = sns.FacetGrid(data=churn_df, col="Churn Label", palette='husl', hue="Satisfaction Score", height=4.5, aspect=1.75)
g.map_dataframe(sns.countplot, "Internet Type")
g.add_legend()
g.fig.suptitle('Customer Churn with Internet Type by Satisfaction Score', fontsize=12)
plt.show()

# %% [markdown]
# We can see that the satisfaction scores for customers who churned with the Fiber Optic Internet Type are very low, indicating that churned users are not satisfied with their Fiber Optic internet connection.

# %% [markdown]
# ### ➕ Putting it all together
#
# The objectives of analyzing these three cities specifically were:
# * to explore the characteristics of churned users in the three biggest cities that comprised most of our userbase
# * to find any differences in user behaviour across these three cities.
#
# <p align="justify"> Across Los Angeles, San Diego, and San Jose, the characteristics of users remain mostly the same, particularly: both senior citizens and under 30 users aren't likely to churn, majority of the churned users are a month-to-month contract, most of the churned users cited switching to a competitor as the main reason for leaving our services, and that the customer lifetime values of retained users was more than that of churned users, and majority of the churned users across the three cities had a fiber optic internet connection.
#
#
# <p align="justify">However, important differences also exist across these two cities. Excluding switching to a competitor (which is the most cited reason across all three states), users in Los Angeles cited pricing and dissatisfaction as reasons for leaving, users in San Diego cited dissatisfaction and attitude of the customer support staff as reasons for leaving, while users in San Jose cited dissatisfaction and other reasons for leaving. Furthermore, churned users varied by the type of marketing offer they last accepted across all three cities. Many users who accepted Offer D in San Jose churned while none of the users who accepted Offer D in San Diego churned. Similarly, the cases vary for all offer types across the three cities.
#
# <p align="justify">Aside from switching to a competitor, churned users cited pricing, dissatisfaction, and attitude of the customer support staff as reasons for leaving. This category of attitude should not be ignored as it represents a portion of churned users that can easily be retained with better customer care and service practices. Further training of the customer support staff can help alleviate this issue and reduce the churn rate. Dissatisfaction with our services can generally mean anything from dissatisfaction with the performance to dissatisfaction with how we've been able to address the users' complaints and concerns. If we're able to reduce the churn rate by improving the training of our customer support staff, we can address the dissatisfaction complaints in part. However, to completely address them, it is vital that we focus on improving our services as a whole. A vast majority of our churned users switched to a competitor perhaps because the competitor was offering better performance at the same or lower price. By working on our services, optimizing them and making them more efficient, we may be able to reach the performance levels offered by our competitors while also lowering our prices. However for this, a thorough competitor analysis as well as an internal analysis of our services is required to pinpoint weak areas and improve them. One such area that likely needs improvement is the Fiber Optic internet service. Most customers who churned are unsatisfied with this connection type and churn, probably due to either dissatisfaction with services or switching to a competitor. Improving this service could likely result in reduced customer attrition.
#
# <p align="justify"> It is also important to note that some of the marketing offers targeted towards the users are having varying degrees of success from city to city. Customers that have accepted a specific offer in one city do not churn while those who have accepted the same offer in another city end up churning. Further analysis of, and customer feedback on these offers is required to evaluate and improve them.
# </p>
# </p>
# </p>

# %% [markdown]
# ## 🧮 Modeling and Prediction

# %% [markdown]
# In order to build a customer attrition prediction model, we first have to drop certain variables.
#
# * **Churn Category**: As we are trying to predict the target column "Churn Label", the "Churn Category" feature should be dropped as it is directly related to the target column.
# * **Latitude and Longitude**: Both of these features would not be of much use in predicting whether or not a given customer will churn. Furthermore, this information is technically already captured in the "City" feature.
# * **Churn Score**: This feature is calculated by a prediction model developed by IBM. The higher this feature is, the more likely the customer is to churn. I want to develop a model for a case in which such information is not available.

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   City                               7043 non-null   object
#  1   Latitude                           7043 non-null   float64
#  2   Longitude                          7043 non-null   float64
#  3   Gender                             7043 non-null   object
#  4   Senior Citizen                     7043 non-null   object
#  5   Phone Service                      7043 non-null   object
#  6   Multiple Lines                     7043 non-null   object
#  7   Online Security                    7043 non-null   object
#  8   Online Backup                      7043 non-null   object
#  9   Device Protection                  7043 non-null   object
#  10  Tech Support                       7043 non-null   object
# ...

# %%
churn_df = churn_df.drop(["Churn Category", "Latitude", "Longitude", "Churn Score"], axis=1)

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   City                               7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Senior Citizen                     7043 non-null   object
#  3   Phone Service                      7043 non-null   object
#  4   Multiple Lines                     7043 non-null   object
#  5   Online Security                    7043 non-null   object
#  6   Online Backup                      7043 non-null   object
#  7   Device Protection                  7043 non-null   object
#  8   Tech Support                       7043 non-null   object
#  9   Streaming TV                       7043 non-null   object
#  10  Streaming Movies                   7043 non-null   object
# ...

# %% [markdown]
# The dataset contains a number of categorical columns. We have to one-hot encode such features before building a model. The first category in each of the one-hot encoded columns is dropped to avoid multi-collinearity and establish the baseline category.
#
# There are several features in the dataset that contain the "No Internet Service category". I get dummies for these features separately to set their base category as "No Internet Service".

# %%
cat_f = ["Gender", "Senior Citizen", "Phone Service", "Multiple Lines", "Contract",
         "Paperless Billing", "Payment Method", "Under 30", "Married", "Offer",
         "Internet Type", "Device Protection Plan", "Premium Tech Support",
         "Streaming Music", "Unlimited Data"]

nis_f = ["Streaming TV", "Streaming Movies", "Device Protection", "Online Security", "Online Backup",
         "Tech Support"]

churndf_oh = pd.get_dummies(churn_df, columns=cat_f, drop_first=True)

# %%
churndf_oh = pd.get_dummies(churndf_oh, columns=nis_f, drop_first=False)

churndf_oh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 58 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   City                                    7043 non-null   object
#  1   Total Charges                           7043 non-null   float64
#  2   Churn Label                             7043 non-null   object
#  3   CLTV                                    7043 non-null   int64
#  4   Age                                     7043 non-null   int64
#  5   Number of Dependents                    7043 non-null   int64
#  6   Satisfaction Score                      7043 non-null   int64
#  7   Number of Referrals                     7043 non-null   int64
#  8   Tenure in Months                        7043 non-null   int64
#  9   Avg Monthly Long Distance Charges       7043 non-null   float64
# ...

# %%
to_drop = ["Device Protection_No internet service", "Online Security_No internet service", "Online Backup_No internet service",
           "Tech Support_No internet service", "Streaming TV_No internet service", "Streaming Movies_No internet service"]

churndf_oh = churndf_oh.drop(to_drop, axis=1)

churndf_oh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 52 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   City                                    7043 non-null   object
#  1   Total Charges                           7043 non-null   float64
#  2   Churn Label                             7043 non-null   object
#  3   CLTV                                    7043 non-null   int64
#  4   Age                                     7043 non-null   int64
#  5   Number of Dependents                    7043 non-null   int64
#  6   Satisfaction Score                      7043 non-null   int64
#  7   Number of Referrals                     7043 non-null   int64
#  8   Tenure in Months                        7043 non-null   int64
#  9   Avg Monthly Long Distance Charges       7043 non-null   float64
# ...

# %% [markdown]
# One categorical column that is left is the City column. This columns has over 1,000 unique values. One hot encoding this feature will result in our dataset having extremely high cardinality which is not desirable. To tackle this, I keep only the top 5 cities as found in the exploratory data analysis while categorizing all other cities as "Others". Then, this feature is one-hot encoded and "Others" category is dropped to establish it as baseline.

# %%
selected_cities = ['Los Angeles', 'San Diego', 'San Jose', 'Sacramento', 'San Francisco']

city_mapping = {city: city if city in selected_cities else 'Others' for city in churndf_oh['City'].unique()}

churndf_oh['City'] = churndf_oh['City'].replace(city_mapping)
# Out:
# array(['Los Angeles', 'Others', 'San Diego', 'San Francisco', 'San Jose',
#        'Sacramento'], dtype=object)

# %%
churndf_oh = pd.get_dummies(churndf_oh, columns=["City"], drop_first=False)
churndf_oh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 57 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Total Charges                           7043 non-null   float64
#  1   Churn Label                             7043 non-null   object
#  2   CLTV                                    7043 non-null   int64
#  3   Age                                     7043 non-null   int64
#  4   Number of Dependents                    7043 non-null   int64
#  5   Satisfaction Score                      7043 non-null   int64
#  6   Number of Referrals                     7043 non-null   int64
#  7   Tenure in Months                        7043 non-null   int64
#  8   Avg Monthly Long Distance Charges       7043 non-null   float64
#  9   Avg Monthly GB Download                 7043 non-null   int64
# ...

# %%
churndf_oh.drop("City_Others", axis=1, inplace=True)

# %%
churndf_oh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 56 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Total Charges                           7043 non-null   float64
#  1   Churn Label                             7043 non-null   object
#  2   CLTV                                    7043 non-null   int64
#  3   Age                                     7043 non-null   int64
#  4   Number of Dependents                    7043 non-null   int64
#  5   Satisfaction Score                      7043 non-null   int64
#  6   Number of Referrals                     7043 non-null   int64
#  7   Tenure in Months                        7043 non-null   int64
#  8   Avg Monthly Long Distance Charges       7043 non-null   float64
#  9   Avg Monthly GB Download                 7043 non-null   int64
# ...

# %% [markdown]
# Now we move towards the modeling part. We start by defining functions for different metrics.

# %%
def accuracy(y_true, y_preds):
  acc = 0
  for i in range(len(y_true)):
    if y_true[i] == y_preds[i]:
      acc = acc + 1
  acc = acc / len(y_true)
  return acc

# %%
def recall(y_true, y_preds):
  tp = 0
  fn = 0
  for i in range(len(y_true)):
    if y_true[i]=="Yes" and y_preds[i]=="Yes":
      tp = tp + 1
    if y_true[i]=="Yes" and y_preds[i]=="No":
      fn = fn + 1
  rec = tp/(tp+fn)
  return rec

# %%
def precision(y_true, y_preds):
  tp = 0
  fp = 0
  for i in range(len(y_true)):
    if y_true[i]=="Yes" and y_preds[i]=="Yes":
      tp = tp + 1
    if y_true[i]=="No" and y_preds[i]=="Yes":
      fp = fp + 1
  prec = tp/(tp+fp)
  return prec

# %%
def f1_score(y_true, y_preds):
  rec = recall(y_true, y_preds)
  prec = precision(y_true, y_preds)
  f1 = (2*rec*prec)/(rec+prec)
  return f1

# %% [markdown]
# ### ⚖ Class imbalance
#
# Let's check the class imbalance in the dataset.

# %%
churndf_oh["Churn Label"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn Label, dtype: int64

# %% [markdown]
# Majority of the observations belong to the "No" class which means there is class imbalance in the dataset. It is imperative that the class imbalance is dealt with before proceeding towards modeling. This is because:
#
# * When a classifier is trained on an imbalanced dataset, it becomes biased towards the majority class. As a result, it may excel at predicting the majority class but perform poorly on the minority class.
#
# * Accuracy may be misleading in the presence of class imbalance. A model that always predicts the majority class can achieve high accuracy but fail to correctly identify the minority class.
#
# * A classifier trained on imbalanced data may not generalize well to new and unseen data, especially when the class distribution in real-world applications differs from the training data. Balancing the dataset can help the model learn more representative patterns, leading to better generalization.
#
# As there is a significant class imbalance, in order to deal with it, I oversample the minority class and undersample the majority class. This will result in minimum overfitting and minimum loss of information.
#
# Prior to this, I split the dataset into train and test sets. After scaling these sets, I create a pipeline to oversample the minority class, undersample the majority class, and run a model for classification. This pipeline is first used for cross validation. Average F1 micro score is obtained to evaluate the cross validation performance before the pipeline is used for training and testing purposes.

# %%
x = churndf_oh.drop("Churn Label", axis=1)
y = churndf_oh["Churn Label"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.15)

# %%
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
pipeline1 = Pipeline([
    ('over', RandomOverSampler(sampling_strategy=.6, random_state=42)),
    ('under', RandomUnderSampler(sampling_strategy=.8, random_state=42)),
    ('model', RandomForestClassifier(random_state=42))
])
scores = cross_val_score(pipeline1, x_train_scaled, y_train, scoring='f1_micro', cv=cv, n_jobs=-1)
meanF1score = np.mean(scores)

# %%
print("Average cross-validation micro F1 score: {:.2f}".format(meanF1score))
# Out:
# Average cross-validation micro F1 score: 0.96

# %% [markdown]
# This score is pretty good, indicating that our sampling technique to deal with the class imbalance has worked well with our dataset. Now using the pipeline defined above, we train our model on the entire training data and make predictions on the test data.

# %% [markdown]
# ### 🔮Prediction
#
# Now we train the model pipeline on the training data, use it to make predictions, and finally evaluate the model.

# %%
pipeline1.fit(x_train_scaled, y_train)
# Out:
# Pipeline(steps=[('over',
#                  RandomOverSampler(random_state=42, sampling_strategy=0.6)),
#                 ('under',
#                  RandomUnderSampler(random_state=42, sampling_strategy=0.8)),
#                 ('model', RandomForestClassifier(random_state=42))])

# %%
y_preds = pipeline1.predict(x_test_scaled)

# %% [markdown]
# ### 🎯Evaluation
#
# After getting predictions from our model, it's time to evaluate the results.

# %%
conf_matrix = confusion_matrix(y_test, y_preds)
cm_df = pd.DataFrame(conf_matrix, index=['Actual 0', 'Actual 1'], columns=['Predicted 0', 'Predicted 1'])
plt.figure(figsize=(6, 4))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.show()

# %%
accuracy_metric = accuracy(y_test.to_numpy(), y_preds)
print("Accuracy: {:.2f}%".format(accuracy_metric*100))

recall_metric = recall(y_test.to_numpy(), y_preds)
print("Recall: {:.2f}%".format(recall_metric*100))

precision_metric = precision(y_test.to_numpy(), y_preds)
print("Precision: {:.2f}%".format(precision_metric*100))

f1_metric = f1_score(y_test.to_numpy(), y_preds)
print("F1 Score: {:.2f}%".format(f1_metric*100))
# Out:
# Accuracy: 95.27%
# Recall: 87.91%
# Precision: 93.39%
# F1 Score: 90.57%

# %% [markdown]
# The model achieves a 95.27% accuracy as well as a 90.57% F1 score. This is really good for a dataset with significant class imbalance, which means that our technique to oversample the minority class as well as undersample the majority class has worked well to generalize the patterns for unseen data.
